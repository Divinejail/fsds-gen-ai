# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
img = Image.open(r'C:\Users\adity\OneDrive\Desktop\pahune mandali\IMG-20230316-WA0104.jpg') # oprn image

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x529>

# %%
myimg = Image.open(r'C:\Users\adity\OneDrive\Desktop\pahune mandali\265e03999ab94e2288fdc23fdbcd5953.jpg')

# %%
myimg
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x1280>

# %%
type(myimg)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
myimg_arr = np.asarray(myimg)
myimg_arr
# Out:
# array([[[209, 215, 213],
#         [209, 215, 213],
#         [210, 216, 214],
#         ...,
#         [117, 108, 109],
#         [133, 127, 127],
#         [113, 109, 108]],
#
#        [[212, 218, 216],
#         [212, 218, 216],
#         [212, 218, 216],
#         ...,
#         [114, 105, 106],
#         [129, 123, 123],
#         [108, 104, 103]],
#
#        [[210, 219, 216],
#         [210, 219, 216],
#         [210, 219, 216],
#         ...,
#         [111, 102, 103],
#         [125, 119, 119],
#         [104, 100,  99]],
#
#        ...,
#
#        [[153, 148, 142],
#         [153, 148, 142],
#         [153, 148, 142],
#         ...,
#         [132, 121, 117],
#         [133, 122, 118],
#         [134, 123, 119]],
#
#        [[153, 148, 142],
#         [152, 147, 141],
#         [152, 147, 141],
#         ...,
#         [132, 121, 117],
#         [133, 122, 118],
#         [134, 123, 119]],
#
#        [[152, 147, 141],
#         [152, 147, 141],
#         [152, 147, 141],
# ...
